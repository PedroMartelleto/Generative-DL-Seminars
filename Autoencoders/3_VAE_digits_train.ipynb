# %% [markdown]
# # Autoencoder variacional - Treino

# %% [markdown]
# # 1 - O problema com os autoencoders tradicionais

# %% [markdown]
# ## Como geramos novos pontos?

# %% [markdown]
# ## **A ideia:** Se o espaço latente (imagem do encoder) seguir uma distribuição regular o suficiente, podemos aleatoriamente escolher um ponto x no espaço latente e, com  D(x), gerar a imagem de um novo dígito.

# %% [markdown]
# ## **O problema:** Não podemos garantir uma distribuição conveniente do espaço latente.

# %% [markdown]
# ![title](img/AE_Problem.jpg)

# %% [markdown]
# ## 1. A distribuição não é limitada ou simétrica. Ou seja, é desconhecida.
#
# ## 2. A área de representação dos dígitos varia muito.
#
# ## 3. Grandes espaços vazios.

# %% [markdown]
# # 2 - A solução

# %% [markdown]
# ## 2.1 - A normal multivariada

# %% [markdown]
# ## 2.2 - Mapeamento dos pontos a uma distribuição

# %% [markdown]
# ![title](img/NormalDistrib.jpg)

# %% [markdown]
# ![title](img/VariationalDistri.jpg)

# %% [markdown]
# ## 2.3 - O que significa "sample de uma distribuição"

# %% [markdown]
# ![title](img/car_colors.gif)

# %% [markdown]
# # 3 - Regularização

# %% [markdown]
# ## - Resolvemos o problema 1. Mas como garantir que os valores da média e variância sejam razoáveis?
#
# ## - Queremos: completude e continuidade

# %% [markdown]
# ## **Solução:** Alterar a Loss Function

# %% [markdown]
# ## Divergência de Kullback-Leibler

# %% [markdown]
# ![title](img/KLLoss.png)

# %% [markdown]
# ![title](img/WithoutWithReg.png)

# %% [markdown]
# ![title](img/MorphGrad.png)

# %% [markdown]
# ## Loss function = r_loss_factor * r_loss + kl_divergence

# %% [markdown]
# ## **Tradeoff do r_loss_factor:**
#
# ## - Se for muito grande, recaímos nos problemas do autoencoder inicial.
#
# ## - Se for muito pequeno, o espaço latente será regular, porém irá gerar reconstruções de baixa qualidade.

# %% [markdown]
# # 4 - O código

# %%
import os

from models.VAE import VariationalAutoencoder
from utils.loaders import load_mnist

# %%
# run params
SECTION = 'vae'
RUN_ID = '0002'
DATA_NAME = 'digits'
RUN_FOLDER = 'run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

if not os.path.exists(RUN_FOLDER):
    os.mkdir(RUN_FOLDER)
    os.mkdir(os.path.join(RUN_FOLDER, 'viz'))
    os.mkdir(os.path.join(RUN_FOLDER, 'images'))
    os.mkdir(os.path.join(RUN_FOLDER, 'weights'))

mode =  'build' #'load' #

# %%
(x_train, y_train), (x_test, y_test) = load_mnist()

# %% [markdown]
# # 5 - Criação da Rede Neural

# %%
from tensorflow.python.framework.ops import disable_eager_execution

vae = VariationalAutoencoder(
    input_dim = (28,28,1)
    , encoder_conv_filters = [32,64,64, 64]
    , encoder_conv_kernel_size = [3,3,3,3]
    , encoder_conv_strides = [1,2,2,1]
    , decoder_conv_t_filters = [64,64,32,1]
    , decoder_conv_t_kernel_size = [3,3,3,3]
    , decoder_conv_t_strides = [1,2,2,1]
    , z_dim = 2
)

if mode == 'build':
    vae.save(RUN_FOLDER)
else:
    vae.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))

# %%
vae.encoder.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# encoder_conv_0 (Conv2D)         (None, 28, 28, 32)   320         encoder_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 28, 28, 32)   0           encoder_conv_0[0][0]
# __________________________________________________________________________________________________
# encoder_conv_1 (Conv2D)         (None, 14, 14, 64)   18496       leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 14, 14, 64)   0           encoder_conv_1[0][0]
# __________________________________________________________________________________________________
# encoder_conv_2 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 7, 7, 64)     0           encoder_conv_2[0][0]
# __________________________________________________________________________________________________
# encoder_conv_3 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 7, 7, 64)     0           encoder_conv_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 3136)         0           leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# mu (Dense)                      (None, 2)            6274        flatten_1[0][0]
# __________________________________________________________________________________________________
# log_var (Dense)                 (None, 2)            6274        flatten_1[0][0]
# __________________________________________________________________________________________________
# encoder_output (Lambda)         (None, 2)            0           mu[0][0]
#                                                                  log_var[0][0]
# ==================================================================================================
# Total params: 105,220
# Trainable params: 105,220
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
vae.decoder.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 2)]               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3136)              9408
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_0 (Conv2DTran (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_1 (Conv2DTran (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 14, 14, 64)        0
# _________________________________________________________________
# decoder_conv_t_2 (Conv2DTran (None, 28, 28, 32)        18464
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 28, 28, 32)        0
# _________________________________________________________________
# decoder_conv_t_3 (Conv2DTran (None, 28, 28, 1)         289
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 6 - Treino da Rede Neural

# %%
LEARNING_RATE = 0.0005
R_LOSS_FACTOR = 1000

# %%
vae.compile(LEARNING_RATE, R_LOSS_FACTOR)

# %%
BATCH_SIZE = 32
EPOCHS = 200
PRINT_EVERY_N_BATCHES = 100
INITIAL_EPOCH = 0

# %%
vae.train(     
    x_train
    , batch_size = BATCH_SIZE
    , epochs = EPOCHS
    , run_folder = RUN_FOLDER
    , print_every_n_batches = PRINT_EVERY_N_BATCHES
    , initial_epoch = INITIAL_EPOCH
)
# Out:
# Train on 60000 samples
# Epoch 1/200
#    96/60000 [..............................] - ETA: 3:47 - loss: 230.4904 - vae_r_loss: 230.4890 - vae_kl_loss: 0.0015
# C:\Users\Pedro\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\keras\engine\training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 60000/60000 [==============================] - ETA: 0s - loss: 58.8257 - vae_r_loss: 55.6236 - vae_kl_loss: 3.2020
# Epoch 00001: saving model to run/vae/0002_digits\weights\weights-001-58.83.h5
#
# Epoch 00001: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 68s 1ms/sample - loss: 58.8257 - vae_r_loss: 55.6236 - vae_kl_loss: 3.2020
# Epoch 2/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 51.9720 - vae_r_loss: 48.0950 - vae_kl_loss: 3.8770
# Epoch 00002: saving model to run/vae/0002_digits\weights\weights-002-51.97.h5
#
# Epoch 00002: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 51.9722 - vae_r_loss: 48.0952 - vae_kl_loss: 3.8770
# Epoch 3/200
# 60000/60000 [==============================] - ETA: 0s - loss: 50.2820 - vae_r_loss: 46.0787 - vae_kl_loss: 4.2033
# Epoch 00003: saving model to run/vae/0002_digits\weights\weights-003-50.28.h5
#
# Epoch 00003: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 50.2820 - vae_r_loss: 46.0787 - vae_kl_loss: 4.2033
# Epoch 4/200
# 60000/60000 [==============================] - ETA: 0s - loss: 49.3010 - vae_r_loss: 44.9038 - vae_kl_loss: 4.3971
# Epoch 00004: saving model to run/vae/0002_digits\weights\weights-004-49.30.h5
#
# Epoch 00004: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 49.3010 - vae_r_loss: 44.9038 - vae_kl_loss: 4.3971
# Epoch 5/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 48.6263 - vae_r_loss: 44.0976 - vae_kl_loss: 4.5287
# Epoch 00005: saving model to run/vae/0002_digits\weights\weights-005-48.62.h5
#
# Epoch 00005: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 48.6234 - vae_r_loss: 44.0945 - vae_kl_loss: 4.5289
# Epoch 6/200
# 60000/60000 [==============================] - ETA: 0s - loss: 48.1683 - vae_r_loss: 43.5326 - vae_kl_loss: 4.6358
# Epoch 00006: saving model to run/vae/0002_digits\weights\weights-006-48.17.h5
#
# Epoch 00006: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 48.1683 - vae_r_loss: 43.5326 - vae_kl_loss: 4.6358
# Epoch 7/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 47.7722 - vae_r_loss: 43.0589 - vae_kl_loss: 4.7134
# Epoch 00007: saving model to run/vae/0002_digits\weights\weights-007-47.77.h5
#
# Epoch 00007: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 47.7715 - vae_r_loss: 43.0580 - vae_kl_loss: 4.7135
# Epoch 8/200
# 60000/60000 [==============================] - ETA: 0s - loss: 47.4558 - vae_r_loss: 42.6876 - vae_kl_loss: 4.7682
# Epoch 00008: saving model to run/vae/0002_digits\weights\weights-008-47.46.h5
#
# Epoch 00008: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 47.4558 - vae_r_loss: 42.6876 - vae_kl_loss: 4.7682
# Epoch 9/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 47.1998 - vae_r_loss: 42.3747 - vae_kl_loss: 4.8251
# Epoch 00009: saving model to run/vae/0002_digits\weights\weights-009-47.20.h5
#
# Epoch 00009: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 68s 1ms/sample - loss: 47.1966 - vae_r_loss: 42.3716 - vae_kl_loss: 4.8251
# Epoch 10/200
# 60000/60000 [==============================] - ETA: 0s - loss: 46.9467 - vae_r_loss: 42.0765 - vae_kl_loss: 4.8703
# Epoch 00010: saving model to run/vae/0002_digits\weights\weights-010-46.95.h5
#
# Epoch 00010: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 46.9467 - vae_r_loss: 42.0765 - vae_kl_loss: 4.8703
# Epoch 11/200
# 60000/60000 [==============================] - ETA: 0s - loss: 46.7242 - vae_r_loss: 41.8313 - vae_kl_loss: 4.8930
# Epoch 00011: saving model to run/vae/0002_digits\weights\weights-011-46.72.h5
#
# Epoch 00011: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 68s 1ms/sample - loss: 46.7242 - vae_r_loss: 41.8313 - vae_kl_loss: 4.8930
# Epoch 12/200
# 60000/60000 [==============================] - ETA: 0s - loss: 46.5775 - vae_r_loss: 41.6330 - vae_kl_loss: 4.9446
# Epoch 00012: saving model to run/vae/0002_digits\weights\weights-012-46.58.h5
#
# Epoch 00012: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 68s 1ms/sample - loss: 46.5775 - vae_r_loss: 41.6330 - vae_kl_loss: 4.9446
# Epoch 13/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 46.4037 - vae_r_loss: 41.4417 - vae_kl_loss: 4.9620
# Epoch 00013: saving model to run/vae/0002_digits\weights\weights-013-46.40.h5
#
# Epoch 00013: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 46.4049 - vae_r_loss: 41.4430 - vae_kl_loss: 4.9619
# Epoch 14/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 46.2729 - vae_r_loss: 41.2844 - vae_kl_loss: 4.9886
# Epoch 00014: saving model to run/vae/0002_digits\weights\weights-014-46.27.h5
#
# Epoch 00014: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 46.2741 - vae_r_loss: 41.2855 - vae_kl_loss: 4.9886
# Epoch 15/200
# 60000/60000 [==============================] - ETA: 0s - loss: 46.1417 - vae_r_loss: 41.1244 - vae_kl_loss: 5.0174
# Epoch 00015: saving model to run/vae/0002_digits\weights\weights-015-46.14.h5
#
# Epoch 00015: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 70s 1ms/sample - loss: 46.1417 - vae_r_loss: 41.1244 - vae_kl_loss: 5.0174
# Epoch 16/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 46.0193 - vae_r_loss: 40.9845 - vae_kl_loss: 5.0348
# Epoch 00016: saving model to run/vae/0002_digits\weights\weights-016-46.02.h5
#
# Epoch 00016: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 70s 1ms/sample - loss: 46.0237 - vae_r_loss: 40.9890 - vae_kl_loss: 5.0347
# Epoch 17/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 45.9355 - vae_r_loss: 40.8838 - vae_kl_loss: 5.0517
# Epoch 00017: saving model to run/vae/0002_digits\weights\weights-017-45.93.h5
#
# Epoch 00017: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 68s 1ms/sample - loss: 45.9312 - vae_r_loss: 40.8795 - vae_kl_loss: 5.0517
# Epoch 18/200
# 60000/60000 [==============================] - ETA: 0s - loss: 45.8208 - vae_r_loss: 40.7580 - vae_kl_loss: 5.0628
# Epoch 00018: saving model to run/vae/0002_digits\weights\weights-018-45.82.h5
#
# Epoch 00018: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 45.8208 - vae_r_loss: 40.7580 - vae_kl_loss: 5.0628
# Epoch 19/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 45.7415 - vae_r_loss: 40.6573 - vae_kl_loss: 5.0842
# Epoch 00019: saving model to run/vae/0002_digits\weights\weights-019-45.74.h5
#
# Epoch 00019: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 45.7449 - vae_r_loss: 40.6606 - vae_kl_loss: 5.0843
# Epoch 20/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 45.6562 - vae_r_loss: 40.5647 - vae_kl_loss: 5.0914
# Epoch 00020: saving model to run/vae/0002_digits\weights\weights-020-45.65.h5
#
# Epoch 00020: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 62s 1ms/sample - loss: 45.6543 - vae_r_loss: 40.5629 - vae_kl_loss: 5.0914
# Epoch 21/200
# 60000/60000 [==============================] - ETA: 0s - loss: 45.5247 - vae_r_loss: 40.4128 - vae_kl_loss: 5.1119
# Epoch 00021: saving model to run/vae/0002_digits\weights\weights-021-45.52.h5
#
# Epoch 00021: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 62s 1ms/sample - loss: 45.5247 - vae_r_loss: 40.4128 - vae_kl_loss: 5.1119
# Epoch 22/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 45.5295 - vae_r_loss: 40.4047 - vae_kl_loss: 5.1248
# Epoch 00022: saving model to run/vae/0002_digits\weights\weights-022-45.53.h5
#
# Epoch 00022: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 64s 1ms/sample - loss: 45.5301 - vae_r_loss: 40.4051 - vae_kl_loss: 5.1250
# Epoch 23/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 45.4350 - vae_r_loss: 40.3036 - vae_kl_loss: 5.1315
# Epoch 00023: saving model to run/vae/0002_digits\weights\weights-023-45.43.h5
#
# Epoch 00023: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 70s 1ms/sample - loss: 45.4326 - vae_r_loss: 40.3010 - vae_kl_loss: 5.1317
# Epoch 24/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 45.3359 - vae_r_loss: 40.1972 - vae_kl_loss: 5.1387
# Epoch 00024: saving model to run/vae/0002_digits\weights\weights-024-45.34.h5
#
# Epoch 00024: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 68s 1ms/sample - loss: 45.3368 - vae_r_loss: 40.1980 - vae_kl_loss: 5.1388
# Epoch 25/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 45.2931 - vae_r_loss: 40.1388 - vae_kl_loss: 5.1543
# Epoch 00025: saving model to run/vae/0002_digits\weights\weights-025-45.30.h5
#
# Epoch 00025: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 45.2953 - vae_r_loss: 40.1411 - vae_kl_loss: 5.1543
# Epoch 26/200
# 60000/60000 [==============================] - ETA: 0s - loss: 45.2505 - vae_r_loss: 40.0855 - vae_kl_loss: 5.1650
# Epoch 00026: saving model to run/vae/0002_digits\weights\weights-026-45.25.h5
#
# Epoch 00026: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 68s 1ms/sample - loss: 45.2505 - vae_r_loss: 40.0855 - vae_kl_loss: 5.1650
# Epoch 27/200
# 60000/60000 [==============================] - ETA: 0s - loss: 45.1757 - vae_r_loss: 40.0004 - vae_kl_loss: 5.1753
# Epoch 00027: saving model to run/vae/0002_digits\weights\weights-027-45.18.h5
#
# Epoch 00027: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 45.1757 - vae_r_loss: 40.0004 - vae_kl_loss: 5.1753
# Epoch 28/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 45.1040 - vae_r_loss: 39.9206 - vae_kl_loss: 5.1834
# Epoch 00028: saving model to run/vae/0002_digits\weights\weights-028-45.10.h5
#
# Epoch 00028: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 45.1039 - vae_r_loss: 39.9206 - vae_kl_loss: 5.1834
# Epoch 29/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 45.0877 - vae_r_loss: 39.8989 - vae_kl_loss: 5.1888
# Epoch 00029: saving model to run/vae/0002_digits\weights\weights-029-45.09.h5
#
# Epoch 00029: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 45.0880 - vae_r_loss: 39.8994 - vae_kl_loss: 5.1887
# Epoch 30/200
# 60000/60000 [==============================] - ETA: 0s - loss: 45.0356 - vae_r_loss: 39.8248 - vae_kl_loss: 5.2108
# Epoch 00030: saving model to run/vae/0002_digits\weights\weights-030-45.04.h5
#
# Epoch 00030: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 45.0356 - vae_r_loss: 39.8248 - vae_kl_loss: 5.2108
# Epoch 31/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.9863 - vae_r_loss: 39.7786 - vae_kl_loss: 5.2077
# Epoch 00031: saving model to run/vae/0002_digits\weights\weights-031-44.99.h5
#
# Epoch 00031: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 44.9863 - vae_r_loss: 39.7786 - vae_kl_loss: 5.2077
# Epoch 32/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.9481 - vae_r_loss: 39.7382 - vae_kl_loss: 5.2100
# Epoch 00032: saving model to run/vae/0002_digits\weights\weights-032-44.95.h5
#
# Epoch 00032: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 44.9481 - vae_r_loss: 39.7382 - vae_kl_loss: 5.2100
# Epoch 33/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.9304 - vae_r_loss: 39.7093 - vae_kl_loss: 5.2210
# Epoch 00033: saving model to run/vae/0002_digits\weights\weights-033-44.93.h5
#
# Epoch 00033: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 70s 1ms/sample - loss: 44.9286 - vae_r_loss: 39.7076 - vae_kl_loss: 5.2210
# Epoch 34/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.8712 - vae_r_loss: 39.6471 - vae_kl_loss: 5.2241
# Epoch 00034: saving model to run/vae/0002_digits\weights\weights-034-44.87.h5
#
# Epoch 00034: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 44.8712 - vae_r_loss: 39.6471 - vae_kl_loss: 5.2241
# Epoch 35/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.8444 - vae_r_loss: 39.6053 - vae_kl_loss: 5.2391
# Epoch 00035: saving model to run/vae/0002_digits\weights\weights-035-44.84.h5
#
# Epoch 00035: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 44.8444 - vae_r_loss: 39.6053 - vae_kl_loss: 5.2391
# Epoch 36/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.7837 - vae_r_loss: 39.5357 - vae_kl_loss: 5.2480
# Epoch 00036: saving model to run/vae/0002_digits\weights\weights-036-44.79.h5
#
# Epoch 00036: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 44.7861 - vae_r_loss: 39.5382 - vae_kl_loss: 5.2480
# Epoch 37/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.7332 - vae_r_loss: 39.4833 - vae_kl_loss: 5.2499
# Epoch 00037: saving model to run/vae/0002_digits\weights\weights-037-44.73.h5
#
# Epoch 00037: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 44.7332 - vae_r_loss: 39.4833 - vae_kl_loss: 5.2499
# Epoch 38/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.7277 - vae_r_loss: 39.4671 - vae_kl_loss: 5.2606
# Epoch 00038: saving model to run/vae/0002_digits\weights\weights-038-44.73.h5
#
# Epoch 00038: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 44.7277 - vae_r_loss: 39.4671 - vae_kl_loss: 5.2606
# Epoch 39/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.6644 - vae_r_loss: 39.3988 - vae_kl_loss: 5.2657
# Epoch 00039: saving model to run/vae/0002_digits\weights\weights-039-44.66.h5
#
# Epoch 00039: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 44.6644 - vae_r_loss: 39.3988 - vae_kl_loss: 5.2657
# Epoch 40/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.6293 - vae_r_loss: 39.3695 - vae_kl_loss: 5.2598
# Epoch 00040: saving model to run/vae/0002_digits\weights\weights-040-44.63.h5
#
# Epoch 00040: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 44.6293 - vae_r_loss: 39.3695 - vae_kl_loss: 5.2598
# Epoch 41/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.6330 - vae_r_loss: 39.3568 - vae_kl_loss: 5.2762
# Epoch 00041: saving model to run/vae/0002_digits\weights\weights-041-44.63.h5
#
# Epoch 00041: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 44.6330 - vae_r_loss: 39.3568 - vae_kl_loss: 5.2762
# Epoch 42/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.5621 - vae_r_loss: 39.2879 - vae_kl_loss: 5.2742
# Epoch 00042: saving model to run/vae/0002_digits\weights\weights-042-44.56.h5
#
# Epoch 00042: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 71s 1ms/sample - loss: 44.5621 - vae_r_loss: 39.2879 - vae_kl_loss: 5.2742
# Epoch 43/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.5432 - vae_r_loss: 39.2598 - vae_kl_loss: 5.2833
# Epoch 00043: saving model to run/vae/0002_digits\weights\weights-043-44.54.h5
#
# Epoch 00043: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 44.5421 - vae_r_loss: 39.2587 - vae_kl_loss: 5.2834
# Epoch 44/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.5039 - vae_r_loss: 39.2203 - vae_kl_loss: 5.2836
# Epoch 00044: saving model to run/vae/0002_digits\weights\weights-044-44.50.h5
#
# Epoch 00044: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 44.5039 - vae_r_loss: 39.2203 - vae_kl_loss: 5.2836
# Epoch 45/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.4784 - vae_r_loss: 39.1927 - vae_kl_loss: 5.2857
# Epoch 00045: saving model to run/vae/0002_digits\weights\weights-045-44.48.h5
#
# Epoch 00045: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 71s 1ms/sample - loss: 44.4778 - vae_r_loss: 39.1920 - vae_kl_loss: 5.2858
# Epoch 46/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.4625 - vae_r_loss: 39.1669 - vae_kl_loss: 5.2955
# Epoch 00046: saving model to run/vae/0002_digits\weights\weights-046-44.46.h5
#
# Epoch 00046: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 44.4633 - vae_r_loss: 39.1677 - vae_kl_loss: 5.2956
# Epoch 47/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.4216 - vae_r_loss: 39.1195 - vae_kl_loss: 5.3021
# Epoch 00047: saving model to run/vae/0002_digits\weights\weights-047-44.42.h5
#
# Epoch 00047: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 71s 1ms/sample - loss: 44.4191 - vae_r_loss: 39.1170 - vae_kl_loss: 5.3021
# Epoch 48/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.3869 - vae_r_loss: 39.0718 - vae_kl_loss: 5.3151
# Epoch 00048: saving model to run/vae/0002_digits\weights\weights-048-44.39.h5
#
# Epoch 00048: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 44.3862 - vae_r_loss: 39.0711 - vae_kl_loss: 5.3152
# Epoch 49/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.3630 - vae_r_loss: 39.0577 - vae_kl_loss: 5.3053
# Epoch 00049: saving model to run/vae/0002_digits\weights\weights-049-44.36.h5
#
# Epoch 00049: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 44.3636 - vae_r_loss: 39.0585 - vae_kl_loss: 5.3052
# Epoch 50/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.3513 - vae_r_loss: 39.0490 - vae_kl_loss: 5.3024
# Epoch 00050: saving model to run/vae/0002_digits\weights\weights-050-44.35.h5
#
# Epoch 00050: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 44.3510 - vae_r_loss: 39.0486 - vae_kl_loss: 5.3024
# Epoch 51/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.3200 - vae_r_loss: 39.0051 - vae_kl_loss: 5.3150
# Epoch 00051: saving model to run/vae/0002_digits\weights\weights-051-44.32.h5
#
# Epoch 00051: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 44.3200 - vae_r_loss: 39.0051 - vae_kl_loss: 5.3150
# Epoch 52/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.3373 - vae_r_loss: 39.0106 - vae_kl_loss: 5.3267
# Epoch 00052: saving model to run/vae/0002_digits\weights\weights-052-44.34.h5
#
# Epoch 00052: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 64s 1ms/sample - loss: 44.3373 - vae_r_loss: 39.0106 - vae_kl_loss: 5.3267
# Epoch 53/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.2879 - vae_r_loss: 38.9523 - vae_kl_loss: 5.3355
# Epoch 00053: saving model to run/vae/0002_digits\weights\weights-053-44.29.h5
#
# Epoch 00053: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 44.2879 - vae_r_loss: 38.9523 - vae_kl_loss: 5.3355
# Epoch 54/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.2662 - vae_r_loss: 38.9398 - vae_kl_loss: 5.3264
# Epoch 00054: saving model to run/vae/0002_digits\weights\weights-054-44.27.h5
#
# Epoch 00054: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 44.2662 - vae_r_loss: 38.9398 - vae_kl_loss: 5.3264
# Epoch 55/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.2250 - vae_r_loss: 38.8881 - vae_kl_loss: 5.3369
# Epoch 00055: saving model to run/vae/0002_digits\weights\weights-055-44.22.h5
#
# Epoch 00055: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 64s 1ms/sample - loss: 44.2244 - vae_r_loss: 38.8875 - vae_kl_loss: 5.3369
# Epoch 56/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.2459 - vae_r_loss: 38.9170 - vae_kl_loss: 5.3288
# Epoch 00056: saving model to run/vae/0002_digits\weights\weights-056-44.24.h5
#
# Epoch 00056: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 44.2437 - vae_r_loss: 38.9149 - vae_kl_loss: 5.3289
# Epoch 57/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.1773 - vae_r_loss: 38.8466 - vae_kl_loss: 5.3307
# Epoch 00057: saving model to run/vae/0002_digits\weights\weights-057-44.18.h5
#
# Epoch 00057: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 44.1773 - vae_r_loss: 38.8466 - vae_kl_loss: 5.3307
# Epoch 58/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.1765 - vae_r_loss: 38.8372 - vae_kl_loss: 5.3393
# Epoch 00058: saving model to run/vae/0002_digits\weights\weights-058-44.18.h5
#
# Epoch 00058: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 44.1765 - vae_r_loss: 38.8372 - vae_kl_loss: 5.3393
# Epoch 59/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.1317 - vae_r_loss: 38.7736 - vae_kl_loss: 5.3580
# Epoch 00059: saving model to run/vae/0002_digits\weights\weights-059-44.13.h5
#
# Epoch 00059: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 68s 1ms/sample - loss: 44.1317 - vae_r_loss: 38.7736 - vae_kl_loss: 5.3580
# Epoch 60/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.1439 - vae_r_loss: 38.7900 - vae_kl_loss: 5.3539
# Epoch 00060: saving model to run/vae/0002_digits\weights\weights-060-44.14.h5
#
# Epoch 00060: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 72s 1ms/sample - loss: 44.1439 - vae_r_loss: 38.7900 - vae_kl_loss: 5.3539
# Epoch 61/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.1246 - vae_r_loss: 38.7727 - vae_kl_loss: 5.3519
# Epoch 00061: saving model to run/vae/0002_digits\weights\weights-061-44.13.h5
#
# Epoch 00061: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 70s 1ms/sample - loss: 44.1253 - vae_r_loss: 38.7734 - vae_kl_loss: 5.3518
# Epoch 62/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.1003 - vae_r_loss: 38.7534 - vae_kl_loss: 5.3469
# Epoch 00062: saving model to run/vae/0002_digits\weights\weights-062-44.10.h5
#
# Epoch 00062: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 44.1003 - vae_r_loss: 38.7534 - vae_kl_loss: 5.3469
# Epoch 63/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.0554 - vae_r_loss: 38.6772 - vae_kl_loss: 5.3781
# Epoch 00063: saving model to run/vae/0002_digits\weights\weights-063-44.06.h5
#
# Epoch 00063: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 44.0554 - vae_r_loss: 38.6772 - vae_kl_loss: 5.3781
# Epoch 64/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.0838 - vae_r_loss: 38.7188 - vae_kl_loss: 5.3650
# Epoch 00064: saving model to run/vae/0002_digits\weights\weights-064-44.08.h5
#
# Epoch 00064: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 44.0838 - vae_r_loss: 38.7188 - vae_kl_loss: 5.3650
# Epoch 65/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.0314 - vae_r_loss: 38.6604 - vae_kl_loss: 5.3710
# Epoch 00065: saving model to run/vae/0002_digits\weights\weights-065-44.03.h5
#
# Epoch 00065: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 44.0319 - vae_r_loss: 38.6609 - vae_kl_loss: 5.3710
# Epoch 66/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.0319 - vae_r_loss: 38.6553 - vae_kl_loss: 5.3766
# Epoch 00066: saving model to run/vae/0002_digits\weights\weights-066-44.03.h5
#
# Epoch 00066: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 44.0294 - vae_r_loss: 38.6527 - vae_kl_loss: 5.3766
# Epoch 67/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 44.0247 - vae_r_loss: 38.6493 - vae_kl_loss: 5.3754
# Epoch 00067: saving model to run/vae/0002_digits\weights\weights-067-44.03.h5
#
# Epoch 00067: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 44.0257 - vae_r_loss: 38.6503 - vae_kl_loss: 5.3754
# Epoch 68/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.9915 - vae_r_loss: 38.6146 - vae_kl_loss: 5.3770
# Epoch 00068: saving model to run/vae/0002_digits\weights\weights-068-43.99.h5
#
# Epoch 00068: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 64s 1ms/sample - loss: 43.9908 - vae_r_loss: 38.6139 - vae_kl_loss: 5.3770
# Epoch 69/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.9553 - vae_r_loss: 38.5866 - vae_kl_loss: 5.3687
# Epoch 00069: saving model to run/vae/0002_digits\weights\weights-069-43.96.h5
#
# Epoch 00069: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.9553 - vae_r_loss: 38.5866 - vae_kl_loss: 5.3687
# Epoch 70/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.9706 - vae_r_loss: 38.5943 - vae_kl_loss: 5.3764
# Epoch 00070: saving model to run/vae/0002_digits\weights\weights-070-43.97.h5
#
# Epoch 00070: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.9706 - vae_r_loss: 38.5943 - vae_kl_loss: 5.3764
# Epoch 71/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.9587 - vae_r_loss: 38.5786 - vae_kl_loss: 5.3801
# Epoch 00071: saving model to run/vae/0002_digits\weights\weights-071-43.96.h5
#
# Epoch 00071: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.9584 - vae_r_loss: 38.5783 - vae_kl_loss: 5.3801
# Epoch 72/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.9525 - vae_r_loss: 38.5665 - vae_kl_loss: 5.3860
# Epoch 00072: saving model to run/vae/0002_digits\weights\weights-072-43.95.h5
#
# Epoch 00072: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 64s 1ms/sample - loss: 43.9509 - vae_r_loss: 38.5650 - vae_kl_loss: 5.3859
# Epoch 73/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.9172 - vae_r_loss: 38.5394 - vae_kl_loss: 5.3778
# Epoch 00073: saving model to run/vae/0002_digits\weights\weights-073-43.92.h5
#
# Epoch 00073: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 64s 1ms/sample - loss: 43.9172 - vae_r_loss: 38.5394 - vae_kl_loss: 5.3778
# Epoch 74/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.9372 - vae_r_loss: 38.5518 - vae_kl_loss: 5.3854
# Epoch 00074: saving model to run/vae/0002_digits\weights\weights-074-43.94.h5
#
# Epoch 00074: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.9373 - vae_r_loss: 38.5519 - vae_kl_loss: 5.3854
# Epoch 75/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.8623 - vae_r_loss: 38.4751 - vae_kl_loss: 5.3873
# Epoch 00075: saving model to run/vae/0002_digits\weights\weights-075-43.86.h5
#
# Epoch 00075: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.8623 - vae_r_loss: 38.4751 - vae_kl_loss: 5.3873
# Epoch 76/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.8947 - vae_r_loss: 38.4910 - vae_kl_loss: 5.4038
# Epoch 00076: saving model to run/vae/0002_digits\weights\weights-076-43.90.h5
#
# Epoch 00076: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.8972 - vae_r_loss: 38.4934 - vae_kl_loss: 5.4038
# Epoch 77/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.8471 - vae_r_loss: 38.4403 - vae_kl_loss: 5.4069
# Epoch 00077: saving model to run/vae/0002_digits\weights\weights-077-43.85.h5
#
# Epoch 00077: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.8471 - vae_r_loss: 38.4403 - vae_kl_loss: 5.4069
# Epoch 78/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.8713 - vae_r_loss: 38.4630 - vae_kl_loss: 5.4082
# Epoch 00078: saving model to run/vae/0002_digits\weights\weights-078-43.87.h5
#
# Epoch 00078: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.8699 - vae_r_loss: 38.4617 - vae_kl_loss: 5.4082
# Epoch 79/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.8496 - vae_r_loss: 38.4515 - vae_kl_loss: 5.3982
# Epoch 00079: saving model to run/vae/0002_digits\weights\weights-079-43.85.h5
#
# Epoch 00079: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.8496 - vae_r_loss: 38.4515 - vae_kl_loss: 5.3982
# Epoch 80/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.8492 - vae_r_loss: 38.4441 - vae_kl_loss: 5.4051
# Epoch 00080: saving model to run/vae/0002_digits\weights\weights-080-43.85.h5
#
# Epoch 00080: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.8502 - vae_r_loss: 38.4452 - vae_kl_loss: 5.4050
# Epoch 81/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.8104 - vae_r_loss: 38.4037 - vae_kl_loss: 5.4067
# Epoch 00081: saving model to run/vae/0002_digits\weights\weights-081-43.81.h5
#
# Epoch 00081: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.8104 - vae_r_loss: 38.4037 - vae_kl_loss: 5.4067
# Epoch 82/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.7869 - vae_r_loss: 38.3730 - vae_kl_loss: 5.4138
# Epoch 00082: saving model to run/vae/0002_digits\weights\weights-082-43.79.h5
#
# Epoch 00082: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.7880 - vae_r_loss: 38.3743 - vae_kl_loss: 5.4138
# Epoch 83/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.7755 - vae_r_loss: 38.3619 - vae_kl_loss: 5.4136
# Epoch 00083: saving model to run/vae/0002_digits\weights\weights-083-43.78.h5
#
# Epoch 00083: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.7755 - vae_r_loss: 38.3619 - vae_kl_loss: 5.4136
# Epoch 84/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.7503 - vae_r_loss: 38.3444 - vae_kl_loss: 5.4059
# Epoch 00084: saving model to run/vae/0002_digits\weights\weights-084-43.75.h5
#
# Epoch 00084: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.7503 - vae_r_loss: 38.3444 - vae_kl_loss: 5.4059
# Epoch 85/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.7507 - vae_r_loss: 38.3480 - vae_kl_loss: 5.4026
# Epoch 00085: saving model to run/vae/0002_digits\weights\weights-085-43.75.h5
#
# Epoch 00085: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.7507 - vae_r_loss: 38.3480 - vae_kl_loss: 5.4026
# Epoch 86/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.7318 - vae_r_loss: 38.3164 - vae_kl_loss: 5.4154
# Epoch 00086: saving model to run/vae/0002_digits\weights\weights-086-43.73.h5
#
# Epoch 00086: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.7318 - vae_r_loss: 38.3164 - vae_kl_loss: 5.4154
# Epoch 87/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.7106 - vae_r_loss: 38.2851 - vae_kl_loss: 5.4256
# Epoch 00087: saving model to run/vae/0002_digits\weights\weights-087-43.71.h5
#
# Epoch 00087: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.7119 - vae_r_loss: 38.2863 - vae_kl_loss: 5.4256
# Epoch 88/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.7145 - vae_r_loss: 38.2910 - vae_kl_loss: 5.4234
# Epoch 00088: saving model to run/vae/0002_digits\weights\weights-088-43.71.h5
#
# Epoch 00088: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 43.7145 - vae_r_loss: 38.2910 - vae_kl_loss: 5.4234
# Epoch 89/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.7383 - vae_r_loss: 38.3119 - vae_kl_loss: 5.4264
# Epoch 00089: saving model to run/vae/0002_digits\weights\weights-089-43.74.h5
#
# Epoch 00089: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.7383 - vae_r_loss: 38.3119 - vae_kl_loss: 5.4264
# Epoch 90/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.7018 - vae_r_loss: 38.2715 - vae_kl_loss: 5.4303
# Epoch 00090: saving model to run/vae/0002_digits\weights\weights-090-43.70.h5
#
# Epoch 00090: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 64s 1ms/sample - loss: 43.7018 - vae_r_loss: 38.2715 - vae_kl_loss: 5.4303
# Epoch 91/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.6999 - vae_r_loss: 38.2728 - vae_kl_loss: 5.4271
# Epoch 00091: saving model to run/vae/0002_digits\weights\weights-091-43.70.h5
#
# Epoch 00091: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.7006 - vae_r_loss: 38.2735 - vae_kl_loss: 5.4271
# Epoch 92/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.6930 - vae_r_loss: 38.2789 - vae_kl_loss: 5.4141
# Epoch 00092: saving model to run/vae/0002_digits\weights\weights-092-43.69.h5
#
# Epoch 00092: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.6930 - vae_r_loss: 38.2788 - vae_kl_loss: 5.4142
# Epoch 93/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.6813 - vae_r_loss: 38.2512 - vae_kl_loss: 5.4302
# Epoch 00093: saving model to run/vae/0002_digits\weights\weights-093-43.68.h5
#
# Epoch 00093: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 43.6829 - vae_r_loss: 38.2527 - vae_kl_loss: 5.4302
# Epoch 94/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.6597 - vae_r_loss: 38.2323 - vae_kl_loss: 5.4274
# Epoch 00094: saving model to run/vae/0002_digits\weights\weights-094-43.66.h5
#
# Epoch 00094: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 43.6624 - vae_r_loss: 38.2352 - vae_kl_loss: 5.4273
# Epoch 95/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.6366 - vae_r_loss: 38.2008 - vae_kl_loss: 5.4358
# Epoch 00095: saving model to run/vae/0002_digits\weights\weights-095-43.64.h5
#
# Epoch 00095: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 70s 1ms/sample - loss: 43.6366 - vae_r_loss: 38.2008 - vae_kl_loss: 5.4358
# Epoch 96/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.6105 - vae_r_loss: 38.1696 - vae_kl_loss: 5.4409
# Epoch 00096: saving model to run/vae/0002_digits\weights\weights-096-43.61.h5
#
# Epoch 00096: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 43.6105 - vae_r_loss: 38.1696 - vae_kl_loss: 5.4409
# Epoch 97/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.6479 - vae_r_loss: 38.2093 - vae_kl_loss: 5.4386
# Epoch 00097: saving model to run/vae/0002_digits\weights\weights-097-43.65.h5
#
# Epoch 00097: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 43.6479 - vae_r_loss: 38.2093 - vae_kl_loss: 5.4386
# Epoch 98/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.5775 - vae_r_loss: 38.1315 - vae_kl_loss: 5.4461
# Epoch 00098: saving model to run/vae/0002_digits\weights\weights-098-43.58.h5
#
# Epoch 00098: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 43.5761 - vae_r_loss: 38.1299 - vae_kl_loss: 5.4462
# Epoch 99/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.6041 - vae_r_loss: 38.1590 - vae_kl_loss: 5.4452
# Epoch 00099: saving model to run/vae/0002_digits\weights\weights-099-43.61.h5
#
# Epoch 00099: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 43.6056 - vae_r_loss: 38.1605 - vae_kl_loss: 5.4452
# Epoch 100/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.5415 - vae_r_loss: 38.1060 - vae_kl_loss: 5.4355
# Epoch 00100: saving model to run/vae/0002_digits\weights\weights-100-43.54.h5
#
# Epoch 00100: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 43.5415 - vae_r_loss: 38.1060 - vae_kl_loss: 5.4355
# Epoch 101/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.5876 - vae_r_loss: 38.1412 - vae_kl_loss: 5.4465
# Epoch 00101: saving model to run/vae/0002_digits\weights\weights-101-43.59.h5
#
# Epoch 00101: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 70s 1ms/sample - loss: 43.5876 - vae_r_loss: 38.1412 - vae_kl_loss: 5.4465
# Epoch 102/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.5403 - vae_r_loss: 38.0887 - vae_kl_loss: 5.4516
# Epoch 00102: saving model to run/vae/0002_digits\weights\weights-102-43.54.h5
#
# Epoch 00102: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.5402 - vae_r_loss: 38.0885 - vae_kl_loss: 5.4517
# Epoch 103/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.5416 - vae_r_loss: 38.0978 - vae_kl_loss: 5.4438
# Epoch 00103: saving model to run/vae/0002_digits\weights\weights-103-43.54.h5
#
# Epoch 00103: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 64s 1ms/sample - loss: 43.5416 - vae_r_loss: 38.0978 - vae_kl_loss: 5.4438
# Epoch 104/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.5341 - vae_r_loss: 38.0930 - vae_kl_loss: 5.4411
# Epoch 00104: saving model to run/vae/0002_digits\weights\weights-104-43.53.h5
#
# Epoch 00104: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 64s 1ms/sample - loss: 43.5345 - vae_r_loss: 38.0933 - vae_kl_loss: 5.4412
# Epoch 105/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.5453 - vae_r_loss: 38.0985 - vae_kl_loss: 5.4467
# Epoch 00105: saving model to run/vae/0002_digits\weights\weights-105-43.55.h5
#
# Epoch 00105: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 64s 1ms/sample - loss: 43.5453 - vae_r_loss: 38.0985 - vae_kl_loss: 5.4467
# Epoch 106/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.5038 - vae_r_loss: 38.0479 - vae_kl_loss: 5.4560
# Epoch 00106: saving model to run/vae/0002_digits\weights\weights-106-43.50.h5
#
# Epoch 00106: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.5038 - vae_r_loss: 38.0479 - vae_kl_loss: 5.4560
# Epoch 107/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.5220 - vae_r_loss: 38.0674 - vae_kl_loss: 5.4546
# Epoch 00107: saving model to run/vae/0002_digits\weights\weights-107-43.52.h5
#
# Epoch 00107: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.5220 - vae_r_loss: 38.0674 - vae_kl_loss: 5.4546
# Epoch 108/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.5035 - vae_r_loss: 38.0413 - vae_kl_loss: 5.4622
# Epoch 00108: saving model to run/vae/0002_digits\weights\weights-108-43.50.h5
#
# Epoch 00108: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 73s 1ms/sample - loss: 43.5035 - vae_r_loss: 38.0413 - vae_kl_loss: 5.4622
# Epoch 109/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.5031 - vae_r_loss: 38.0433 - vae_kl_loss: 5.4598
# Epoch 00109: saving model to run/vae/0002_digits\weights\weights-109-43.50.h5
#
# Epoch 00109: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 74s 1ms/sample - loss: 43.5024 - vae_r_loss: 38.0426 - vae_kl_loss: 5.4598
# Epoch 110/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.4754 - vae_r_loss: 38.0184 - vae_kl_loss: 5.4569
# Epoch 00110: saving model to run/vae/0002_digits\weights\weights-110-43.48.h5
#
# Epoch 00110: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 73s 1ms/sample - loss: 43.4754 - vae_r_loss: 38.0186 - vae_kl_loss: 5.4568
# Epoch 111/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.4610 - vae_r_loss: 37.9958 - vae_kl_loss: 5.4652
# Epoch 00111: saving model to run/vae/0002_digits\weights\weights-111-43.46.h5
#
# Epoch 00111: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.4610 - vae_r_loss: 37.9958 - vae_kl_loss: 5.4652
# Epoch 112/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.4689 - vae_r_loss: 37.9872 - vae_kl_loss: 5.4817
# Epoch 00112: saving model to run/vae/0002_digits\weights\weights-112-43.47.h5
#
# Epoch 00112: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 43.4689 - vae_r_loss: 37.9872 - vae_kl_loss: 5.4817
# Epoch 113/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.4359 - vae_r_loss: 37.9762 - vae_kl_loss: 5.4597
# Epoch 00113: saving model to run/vae/0002_digits\weights\weights-113-43.44.h5
#
# Epoch 00113: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.4376 - vae_r_loss: 37.9777 - vae_kl_loss: 5.4598
# Epoch 114/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.4667 - vae_r_loss: 37.9986 - vae_kl_loss: 5.4682
# Epoch 00114: saving model to run/vae/0002_digits\weights\weights-114-43.47.h5
#
# Epoch 00114: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.4667 - vae_r_loss: 37.9986 - vae_kl_loss: 5.4682
# Epoch 115/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.4524 - vae_r_loss: 37.9822 - vae_kl_loss: 5.4702
# Epoch 00115: saving model to run/vae/0002_digits\weights\weights-115-43.45.h5
#
# Epoch 00115: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 72s 1ms/sample - loss: 43.4524 - vae_r_loss: 37.9822 - vae_kl_loss: 5.4702
# Epoch 116/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.4459 - vae_r_loss: 37.9689 - vae_kl_loss: 5.4770
# Epoch 00116: saving model to run/vae/0002_digits\weights\weights-116-43.45.h5
#
# Epoch 00116: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.4459 - vae_r_loss: 37.9689 - vae_kl_loss: 5.4770
# Epoch 117/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.4384 - vae_r_loss: 37.9571 - vae_kl_loss: 5.4813
# Epoch 00117: saving model to run/vae/0002_digits\weights\weights-117-43.44.h5
#
# Epoch 00117: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 43.4379 - vae_r_loss: 37.9566 - vae_kl_loss: 5.4813
# Epoch 118/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.4504 - vae_r_loss: 37.9799 - vae_kl_loss: 5.4705
# Epoch 00118: saving model to run/vae/0002_digits\weights\weights-118-43.45.h5
#
# Epoch 00118: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 43.4522 - vae_r_loss: 37.9818 - vae_kl_loss: 5.4705
# Epoch 119/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.4027 - vae_r_loss: 37.9159 - vae_kl_loss: 5.4868
# Epoch 00119: saving model to run/vae/0002_digits\weights\weights-119-43.40.h5
#
# Epoch 00119: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 69s 1ms/sample - loss: 43.4027 - vae_r_loss: 37.9159 - vae_kl_loss: 5.4868
# Epoch 120/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.4273 - vae_r_loss: 37.9475 - vae_kl_loss: 5.4799
# Epoch 00120: saving model to run/vae/0002_digits\weights\weights-120-43.43.h5
#
# ...
# Epoch 161/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.1406 - vae_r_loss: 37.6220 - vae_kl_loss: 5.5185
# Epoch 00161: saving model to run/vae/0002_digits\weights\weights-161-43.14.h5
#
# Epoch 00161: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.1408 - vae_r_loss: 37.6224 - vae_kl_loss: 5.5185
# Epoch 162/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.1562 - vae_r_loss: 37.6228 - vae_kl_loss: 5.5334
# Epoch 00162: saving model to run/vae/0002_digits\weights\weights-162-43.16.h5
#
# Epoch 00162: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.1583 - vae_r_loss: 37.6249 - vae_kl_loss: 5.5334
# Epoch 163/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.1381 - vae_r_loss: 37.6098 - vae_kl_loss: 5.5284
# Epoch 00163: saving model to run/vae/0002_digits\weights\weights-163-43.14.h5
#
# Epoch 00163: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.1381 - vae_r_loss: 37.6098 - vae_kl_loss: 5.5284
# Epoch 164/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.1033 - vae_r_loss: 37.5737 - vae_kl_loss: 5.5296
# Epoch 00164: saving model to run/vae/0002_digits\weights\weights-164-43.10.h5
#
# Epoch 00164: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.1007 - vae_r_loss: 37.5711 - vae_kl_loss: 5.5297
# Epoch 165/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.0995 - vae_r_loss: 37.5659 - vae_kl_loss: 5.5336
# Epoch 00165: saving model to run/vae/0002_digits\weights\weights-165-43.10.h5
#
# Epoch 00165: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.0995 - vae_r_loss: 37.5659 - vae_kl_loss: 5.5336
# Epoch 166/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.1950 - vae_r_loss: 37.6614 - vae_kl_loss: 5.5337
# Epoch 00166: saving model to run/vae/0002_digits\weights\weights-166-43.20.h5
#
# Epoch 00166: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.1950 - vae_r_loss: 37.6614 - vae_kl_loss: 5.5337
# Epoch 167/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.0975 - vae_r_loss: 37.5788 - vae_kl_loss: 5.5187
# Epoch 00167: saving model to run/vae/0002_digits\weights\weights-167-43.10.h5
#
# Epoch 00167: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.0982 - vae_r_loss: 37.5795 - vae_kl_loss: 5.5186
# Epoch 168/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.0864 - vae_r_loss: 37.5563 - vae_kl_loss: 5.5301
# Epoch 00168: saving model to run/vae/0002_digits\weights\weights-168-43.09.h5
#
# Epoch 00168: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.0864 - vae_r_loss: 37.5563 - vae_kl_loss: 5.5301
# Epoch 169/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.0825 - vae_r_loss: 37.5477 - vae_kl_loss: 5.5347
# Epoch 00169: saving model to run/vae/0002_digits\weights\weights-169-43.08.h5
#
# Epoch 00169: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.0825 - vae_r_loss: 37.5477 - vae_kl_loss: 5.5347
# Epoch 170/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.0848 - vae_r_loss: 37.5553 - vae_kl_loss: 5.5294
# Epoch 00170: saving model to run/vae/0002_digits\weights\weights-170-43.08.h5
#
# Epoch 00170: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.0848 - vae_r_loss: 37.5553 - vae_kl_loss: 5.5294
# Epoch 171/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.0888 - vae_r_loss: 37.5452 - vae_kl_loss: 5.5436
# Epoch 00171: saving model to run/vae/0002_digits\weights\weights-171-43.09.h5
#
# Epoch 00171: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.0898 - vae_r_loss: 37.5462 - vae_kl_loss: 5.5436
# Epoch 172/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.0607 - vae_r_loss: 37.5180 - vae_kl_loss: 5.5427
# Epoch 00172: saving model to run/vae/0002_digits\weights\weights-172-43.06.h5
#
# Epoch 00172: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.0607 - vae_r_loss: 37.5180 - vae_kl_loss: 5.5427
# Epoch 173/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.1116 - vae_r_loss: 37.5701 - vae_kl_loss: 5.5414
# Epoch 00173: saving model to run/vae/0002_digits\weights\weights-173-43.11.h5
#
# Epoch 00173: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.1116 - vae_r_loss: 37.5701 - vae_kl_loss: 5.5414
# Epoch 174/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.0770 - vae_r_loss: 37.5266 - vae_kl_loss: 5.5503
# Epoch 00174: saving model to run/vae/0002_digits\weights\weights-174-43.08.h5
#
# Epoch 00174: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.0762 - vae_r_loss: 37.5259 - vae_kl_loss: 5.5503
# Epoch 175/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.0333 - vae_r_loss: 37.4848 - vae_kl_loss: 5.5485
# Epoch 00175: saving model to run/vae/0002_digits\weights\weights-175-43.03.h5
#
# Epoch 00175: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.0333 - vae_r_loss: 37.4848 - vae_kl_loss: 5.5485
# Epoch 176/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.0354 - vae_r_loss: 37.4972 - vae_kl_loss: 5.5383
# Epoch 00176: saving model to run/vae/0002_digits\weights\weights-176-43.04.h5
#
# Epoch 00176: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.0361 - vae_r_loss: 37.4979 - vae_kl_loss: 5.5383
# Epoch 177/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.0578 - vae_r_loss: 37.5191 - vae_kl_loss: 5.5386
# Epoch 00177: saving model to run/vae/0002_digits\weights\weights-177-43.06.h5
#
# Epoch 00177: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.0568 - vae_r_loss: 37.5182 - vae_kl_loss: 5.5386
# Epoch 178/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.0169 - vae_r_loss: 37.4694 - vae_kl_loss: 5.5475
# Epoch 00178: saving model to run/vae/0002_digits\weights\weights-178-43.02.h5
#
# Epoch 00178: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.0181 - vae_r_loss: 37.4706 - vae_kl_loss: 5.5474
# Epoch 179/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.0357 - vae_r_loss: 37.4931 - vae_kl_loss: 5.5425
# Epoch 00179: saving model to run/vae/0002_digits\weights\weights-179-43.04.h5
#
# Epoch 00179: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 43.0356 - vae_r_loss: 37.4930 - vae_kl_loss: 5.5426
# Epoch 180/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.0335 - vae_r_loss: 37.4778 - vae_kl_loss: 5.5556
# Epoch 00180: saving model to run/vae/0002_digits\weights\weights-180-43.03.h5
#
# Epoch 00180: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.0335 - vae_r_loss: 37.4778 - vae_kl_loss: 5.5556
# Epoch 181/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.0445 - vae_r_loss: 37.5016 - vae_kl_loss: 5.5429
# Epoch 00181: saving model to run/vae/0002_digits\weights\weights-181-43.04.h5
#
# Epoch 00181: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.0445 - vae_r_loss: 37.5016 - vae_kl_loss: 5.5429
# Epoch 182/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.0421 - vae_r_loss: 37.5108 - vae_kl_loss: 5.5313
# Epoch 00182: saving model to run/vae/0002_digits\weights\weights-182-43.04.h5
#
# Epoch 00182: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.0421 - vae_r_loss: 37.5108 - vae_kl_loss: 5.5313
# Epoch 183/200
# 60000/60000 [==============================] - ETA: 0s - loss: 43.0339 - vae_r_loss: 37.4940 - vae_kl_loss: 5.5398
# Epoch 00183: saving model to run/vae/0002_digits\weights\weights-183-43.03.h5
#
# Epoch 00183: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.0339 - vae_r_loss: 37.4940 - vae_kl_loss: 5.5398
# Epoch 184/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.0298 - vae_r_loss: 37.4943 - vae_kl_loss: 5.5355
# Epoch 00184: saving model to run/vae/0002_digits\weights\weights-184-43.03.h5
#
# Epoch 00184: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.0308 - vae_r_loss: 37.4953 - vae_kl_loss: 5.5355
# Epoch 185/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 42.9938 - vae_r_loss: 37.4482 - vae_kl_loss: 5.5456
# Epoch 00185: saving model to run/vae/0002_digits\weights\weights-185-42.99.h5
#
# Epoch 00185: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 67s 1ms/sample - loss: 42.9940 - vae_r_loss: 37.4483 - vae_kl_loss: 5.5456
# Epoch 186/200
# 60000/60000 [==============================] - ETA: 0s - loss: 42.9828 - vae_r_loss: 37.4333 - vae_kl_loss: 5.5494
# Epoch 00186: saving model to run/vae/0002_digits\weights\weights-186-42.98.h5
#
# Epoch 00186: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 42.9828 - vae_r_loss: 37.4333 - vae_kl_loss: 5.5494
# Epoch 187/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 42.9917 - vae_r_loss: 37.4361 - vae_kl_loss: 5.5557
# Epoch 00187: saving model to run/vae/0002_digits\weights\weights-187-42.99.h5
#
# Epoch 00187: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 42.9949 - vae_r_loss: 37.4392 - vae_kl_loss: 5.5557
# Epoch 188/200
# 60000/60000 [==============================] - ETA: 0s - loss: 42.9916 - vae_r_loss: 37.4587 - vae_kl_loss: 5.5330
# Epoch 00188: saving model to run/vae/0002_digits\weights\weights-188-42.99.h5
#
# Epoch 00188: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 64s 1ms/sample - loss: 42.9916 - vae_r_loss: 37.4587 - vae_kl_loss: 5.5330
# Epoch 189/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.0400 - vae_r_loss: 37.4938 - vae_kl_loss: 5.5462
# Epoch 00189: saving model to run/vae/0002_digits\weights\weights-189-43.04.h5
#
# Epoch 00189: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 43.0402 - vae_r_loss: 37.4939 - vae_kl_loss: 5.5463
# Epoch 190/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 42.9930 - vae_r_loss: 37.4372 - vae_kl_loss: 5.5558
# Epoch 00190: saving model to run/vae/0002_digits\weights\weights-190-42.99.h5
#
# Epoch 00190: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 42.9918 - vae_r_loss: 37.4360 - vae_kl_loss: 5.5558
# Epoch 191/200
# 60000/60000 [==============================] - ETA: 0s - loss: 42.9521 - vae_r_loss: 37.3923 - vae_kl_loss: 5.5599
# Epoch 00191: saving model to run/vae/0002_digits\weights\weights-191-42.95.h5
#
# Epoch 00191: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 42.9521 - vae_r_loss: 37.3923 - vae_kl_loss: 5.5599
# Epoch 192/200
# 60000/60000 [==============================] - ETA: 0s - loss: 42.9474 - vae_r_loss: 37.3985 - vae_kl_loss: 5.5489
# Epoch 00192: saving model to run/vae/0002_digits\weights\weights-192-42.95.h5
#
# Epoch 00192: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 42.9474 - vae_r_loss: 37.3985 - vae_kl_loss: 5.5489
# Epoch 193/200
# 60000/60000 [==============================] - ETA: 0s - loss: 42.9874 - vae_r_loss: 37.4275 - vae_kl_loss: 5.5599
# Epoch 00193: saving model to run/vae/0002_digits\weights\weights-193-42.99.h5
#
# Epoch 00193: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 42.9874 - vae_r_loss: 37.4275 - vae_kl_loss: 5.5599
# Epoch 194/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 42.9601 - vae_r_loss: 37.4033 - vae_kl_loss: 5.5567
# Epoch 00194: saving model to run/vae/0002_digits\weights\weights-194-42.96.h5
#
# Epoch 00194: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 42.9627 - vae_r_loss: 37.4058 - vae_kl_loss: 5.5569
# Epoch 195/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 43.0000 - vae_r_loss: 37.4537 - vae_kl_loss: 5.5463
# Epoch 00195: saving model to run/vae/0002_digits\weights\weights-195-43.00.h5
#
# Epoch 00195: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 43.0017 - vae_r_loss: 37.4554 - vae_kl_loss: 5.5463
# Epoch 196/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 42.9687 - vae_r_loss: 37.4206 - vae_kl_loss: 5.5481
# Epoch 00196: saving model to run/vae/0002_digits\weights\weights-196-42.97.h5
#
# Epoch 00196: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 42.9685 - vae_r_loss: 37.4202 - vae_kl_loss: 5.5483
# Epoch 197/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 42.9700 - vae_r_loss: 37.4052 - vae_kl_loss: 5.5648
# Epoch 00197: saving model to run/vae/0002_digits\weights\weights-197-42.97.h5
#
# Epoch 00197: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 65s 1ms/sample - loss: 42.9703 - vae_r_loss: 37.4053 - vae_kl_loss: 5.5649
# Epoch 198/200
# 60000/60000 [==============================] - ETA: 0s - loss: 42.9797 - vae_r_loss: 37.4052 - vae_kl_loss: 5.5745
# Epoch 00198: saving model to run/vae/0002_digits\weights\weights-198-42.98.h5
#
# Epoch 00198: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 42.9797 - vae_r_loss: 37.4052 - vae_kl_loss: 5.5745
# Epoch 199/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 42.9958 - vae_r_loss: 37.4307 - vae_kl_loss: 5.5651
# Epoch 00199: saving model to run/vae/0002_digits\weights\weights-199-43.00.h5
#
# Epoch 00199: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 42.9959 - vae_r_loss: 37.4307 - vae_kl_loss: 5.5652
# Epoch 200/200
# 59968/60000 [============================>.] - ETA: 0s - loss: 42.9534 - vae_r_loss: 37.3879 - vae_kl_loss: 5.5655
# Epoch 00200: saving model to run/vae/0002_digits\weights\weights-200-42.95.h5
#
# Epoch 00200: saving model to run/vae/0002_digits\weights\weights.h5
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 42.9513 - vae_r_loss: 37.3859 - vae_kl_loss: 5.5654
